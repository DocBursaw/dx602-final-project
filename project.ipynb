# %% [markdown]
# # DX 602 Final Project

# %% [markdown]
# ## Introduction
#
# In this project, you will practice the skills that you have learned throughout this module with a heavy focus on building models.
# Most of the problems and questions are open ended compared to your previous homeworks, and you will be asked to explain your choices.
# Most of them will have a particular type of solution implied, but it is up to you to figure out the details based on what you have learned in this module.

# %% [markdown]
# ## Instructions
#
# Each problem asks you to perform build models, run a computation, or otherwise perform some analysis of the data, and usually answer some questions about the results.
# Make sure that your question answers are well supported by your analysis and explanations; simply stating an answer without support will earn minimal points.
#
# Notebook cells for code and text have been added for your convenience, but feel free to add additional cells.

# %% [markdown]
# ## Example Code
#
# You may find it helpful to refer to this GitHub repository of Jupyter notebooks for example code.
#
# * https://github.com/bu-cds-omds/dx601-examples
# * https://github.com/bu-cds-omds/dx602-examples
#
# Any calculations demonstrated in code examples or videos may be found in these notebooks, and you are allowed to copy this example code in your homework answers.

# %% [markdown]
# ## Submission
#
# This project will be entirely manually graded.
# However, we may rerun some or all of your code to confirm that it works as described.

# %% [markdown]
# ### Late Policy
#
# The normal homework late policy for OMDS does not apply to this project.
# Boston University requires final grades to be submitted within 72 hours of class instruction ending, so we cannot accommodate 5 days of late submissions.
#
# However, we have delayed the due date of this project to be substantially later than necessary given its scope, and given you more days for submission with full credit than you would have had days for submission with partial credit under the homework late policy.
# The Thanksgiving holiday was also taken into account in setting the deadline.
# Finally, the deadlines for DX 601 and DX 602 were coordinated to be a week apart while giving ample time for both of their projects.

# %% [markdown]
# ## Shared Imports
#
# For this project, you are forbidden to use modules that were not loaded in this template.
# While other modules are handy in practice, modules that trivialize these problems interfere with our assessment of your own knowledge and skills.
#
# If you believe a module covered in the course material (not live sessions) is missing, please check with your learning facilitator.

# %%
import math
import sys

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats
import sklearn.linear_model

# %% [markdown]
# ## Problems

# %% [markdown]
# ### Problem 1 (5 points)
#
# Pick one of the following data sets to analyze in this project.
# Load the data set, and show a random sample of 10 rows.
#
# * [Wine Quality](https://archive.ics.uci.edu/dataset/186/wine+quality) ([PMLB - red subset only](https://github.com/EpistasisLab/pmlb/tree/master/datasets/wine_quality_red))
# * [Body Fat](https://www.openml.org/search?type=data&status=active&id=560) ([PMLB](https://github.com/EpistasisLab/pmlb/tree/master/datasets/560_bodyfat))
#
# The PMLB copies of the data are generally cleaner and recommended for this project, but the other links are provided to give you more context.
# To load the data from the PMLB Github repository, navigate to the `.tsv.gz` file in GitHub and copy the link from the "Raw" button.
#
# If the dataset has missing data, you should drop the rows with missing data before proceeding.
# If the data set you choose has more than ten columns, you may limit later analysis that is requested per column to just the first ten columns.

# %%
# YOUR CODE HERE

path = r"S:\1. Curt Documents\Curt School\Boston\DX602\560_bodyfat.tsv\560_bodyfat.tsv"

print(os.path.exists(path))

df = pd.read_csv(path, sep="\t")
df.sample(10)
# Out:
# True
#      Density   Age      Weight  Height       Neck       Chest     Abdomen  \
# 210   1.0829  49.0  140.500000   68.00  35.799999   91.199997   79.400002
# 141   1.0571  40.0  173.250000   69.50  36.500000   99.500000   93.000000
# 61    1.0317  56.0  178.750000   68.50  35.599998  102.900002   94.699997
# 215   0.9950  51.0  219.000000   64.00  41.200001  119.800003  122.099998
# 66    1.0499  54.0  151.500000   70.75  35.599998   90.000000   83.900002
# 26    1.0811  34.0  131.500000   67.50  36.200001   88.599998   74.599998
# 75    1.0666  61.0  148.250000   67.50  36.000000   91.599998   81.800003
# 174   1.0414  36.0  226.750000   71.75  41.500000  115.300003  108.800003
# 30    1.0716  32.0  182.000000   73.75  38.700001  100.500000   88.699997
# 38    1.0202  46.0  363.149994   72.25  51.200001  136.199997  148.100006
#
#             Hip      Thigh       Knee      Ankle     Biceps    Forearm  \
# 210   89.000000  51.099998  35.000000  21.700001  30.900000  28.799999
# 141   99.300003  60.400002  38.200001  22.000000  32.000000  28.500000
# 61   100.800003  60.900002  38.000000  22.100000  32.500000  29.799999
# 215  112.800003  62.500000  36.900002  23.600000  34.700001  29.100000
# 66    93.900002  55.000000  36.099998  21.700001  29.600000  27.400000
# 26    85.300003  51.700001  34.700001  21.400000  28.700001  27.000000
# 75    94.800003  54.500000  37.000000  21.400000  29.299999  27.000000
# 174  114.400002  69.199997  42.400002  24.000000  35.400002  21.000000
# 30    99.800003  57.500000  38.700001  33.900002  32.500000  27.700001
# 38   147.699997  87.300003  49.099998  29.600000  45.000000  29.000000
#
#          Wrist     target
# 210  17.400000   7.100000
# 141  17.799999  18.299999
# 61   18.299999  29.799999
# 215  18.400000  47.500000
# 66   17.400000  21.500000
# 26   16.500000   7.900000
# 75   18.299999  18.500000
# 174  20.100000  25.299999
# 30   18.400000  11.900000
# 38   21.400000  35.200001

# %% [markdown]
# YOUR ANSWERS HERE

# %% [markdown]
# ### Problem 2 (10 points)
#
# List all of the columns and describe them in your own words.

# %%
# YOUR CODE HERE
df.columns
# Out:
# Index(['Density', 'Age', 'Weight', 'Height', 'Neck', 'Chest', 'Abdomen', 'Hip',
#        'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm', 'Wrist', 'target'],
#       dtype='object')

# %% [markdown]
# YOUR ANSWERS HERE
# 2a.'Density', 'Age', 'Weight', 'Height', 'Neck', 'Chest', 'Abdomen', 'Hip', 'Thigh', 'Knee', 'Ankle', 'Biceps', 'Forearm', 'Wrist', 'target'
# 2b. Density is body fat percentage
# 2c. Age is subject age in years
# 2d. Weight is subject weight in pounds
# 2e. Height is subject height in inches
# 2f. Neck is neck circumference in centimeters
# 2g. Chest is chest circumference in centimeters
# 2h. Abdomen is abdomen circumference in centimeters
# 2i. Hip is hip circumference in centimeters
# 2j. Thigh is thigh circumference in centimeters
# 2k. Knee is knee circumference in centimeters
# 2l. Ankle is ankle circumference in centimeters
# 2m. Biceps is biceps circumference in centimeters
# 2n. Forearm is forearm circumference in centimeters
# 2o. Wrist is wrist circumference in centimeters
# 2p. Target is body fat percentage calculated from density

# %% [markdown]
# ### Problem 3 (50 points)
#
# Perform an exploratory analysis of the data set.
# After your exploratory analysis, pick 3 individual charts that you the think were particularly interesting.
# Repeat those charts separately from your original analysis, and after each of those charts, explain what you thought was noteworthy.

# %%
# YOUR CODE HERE
plt.figure(figsize=(6,4))
plt.hist(df["Age"], bins=20, edgecolor="black")
plt.title("Distribution of Age")
plt.xlabel("Age (years)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# YOUR ANSWERS HERE
# 3a. The histogram indicates subjects are betwween 20-90 with a majority in the middle range.

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["Weight"], df["target"])
plt.title("Weight vs Body Fat Percentage")
plt.xlabel("Weight (lbs)")
plt.ylabel("Body Fat Percentage")
plt.show()

# %% [markdown]
# YOUR ANSWERS HERE
# 3b. The scatter indicates weight does not have a significance as a predictor in body fat.

# %%
plt.figure(figsize=(6,4))
plt.scatter(df["Height"], df["target"])
plt.title("Height vs Body Fat Percentage")
plt.xlabel("Height (inches)")
plt.ylabel("Body Fat Percentage")
plt.show()

# %% [markdown]
# YOUR ANSWERS HERE
# 3c. The scatter indicates that there is no significance with heght and body fat.

# %% [markdown]
# ### Problem 4 (5 points)
#
# Plot the correlation matrix of the numeric columns in the data set.
# Which pair of different columns were highlighted as the most correlated?

# %%
# YOUR CODE HERE

corr_matrix = df.corr()
corr_pairs = corr_matrix.abs().unstack()

corr_pairs = corr_pairs[corr_pairs.index.get_level_values(0) != corr_pairs.index.get_level_values(1)]

best_corr = corr_pairs.idxmax()
best_value = corr_pairs.max()

best_corr, best_value
# Out:
# (('Density', 'target'), np.float64(0.9877824010025148))

# %% [markdown]
# YOUR ANSWERS HERE
# 4. The pair of different columns which are highlighted as the most correlated are Density and Target with a 0.9878 correlation value.

# %% [markdown]
# ### Problem 5 (10 points)
#
# Pick three different regression model classes to try in problem 6 from the scikit-learn documentation.
# For each class, provide a link to the scikit-learn documentation, and a link to another web page describing how that kind of model works.
# The second link should not be from scikit-learn, but Wikipedia is acceptable.
# You do not need to understand the methods at this time, but it is good to be comfortable researching them.

# %%
# YOUR CODE HERE

# %% [markdown]
# 5a. scikit-learn documentation: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression
#     another web page: https://www.geeksforgeeks.org/machine-learning/ml-linear-regression/
#
# 5b. scikit-learn documentation: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html
#     another web page: https://www.ibm.com/think/topics/random-forest
#
# 5c. scikit-learn documentation: https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html
#     another web page: https://towardsdatascience.com/the-math-behind-knn-3d34050efb71/

# %% [markdown]
# #here

# %% [markdown]
# YOUR ANSWERS HERE

# %% [markdown]
# ### Problem 6 (50 points)
#
# Build three different regression models using the entire data set.
# Plot the actual target vs the predicted values for each in one chart.
# Compute the L2 and L1 losses for each of them.
# You may use any regression class provided provided by scikit-learn, and you may reuse one class as long as you change its parameters enough to see different results.

# %%
# YOUR CODE HERE

# %% [markdown]
# YOUR ANSWERS HERE

# %% [markdown]
# ### Problem 7 (30 points)
#
# Use 5-fold cross-validation to repeat building the same three kinds of regression models. Compare the L2 losses predicted by cross-validation against the L2 losses training against the whole data set. (The difference is likely from overfitting in the latter.)

# %%
# YOUR CODE HERE

# %% [markdown]
# YOUR ANSWERS HERE

# %% [markdown]
# ### Problem 8 (25 points)
#
# Build three different regression models as in problem 6, but preprocess the data so that each column has mean zero and standard deviation one first.
# For full credit, use a scikit-learn pipeline for each model.
# For each model, compare the L2 losses -- which of them performed differently from your results in problem 6?
#
# (This process will be covered in week 13.)

# %%
# YOUR CODE HERE

# %% [markdown]
# YOUR ANSWERS HERE

# %% [markdown]
# ### Problem 9 (5 points)
#
# A colleague suggests that you find better models by repeatedly building decision trees with random depth limits.
# They say that trying 1000 such models will likely find an improvement as long as you use cross validation.
# Give a one sentence response to this suggestion.

# %%
# YOUR CODE HERE

# %% [markdown]
# YOUR ANSWERS HERE

# %% [markdown]
# ### Problem 10 (10 points)
#
# Pick a best model from all the models that you built and otherwise described in this project.
# Explain how you picked it, including what criteria you chose, and how the other models compared by that criteria.
# As much as possible, justify that problem in the context of the original data set.

# %%
# YOUR CODE HERE

# %% [markdown]
# YOUR ANSWERS HERE
